# %% [markdown]
# # Lecture 4
# ---

# %% [markdown]
# #### Big Number Duel
#
# What is the largest number you can name?
# * Avogadro constant - $6.02214076 \times 10^{23}$ - number of particles per mol
# * googol - $10^{100}$
# * centillion - $10^{303}$
# * millinillion - $10^{3003}$
# * googolplex - $10^{googol} = 10^{10^{100}}$
#     * btw: these are called "power towers" $10^{10^{10^{10^{10}}}}$
# * Graham's number - larger than what can be represented even using power towers

# %% [markdown]
# What about infinity? Are there different sizes of infinity?
#
# * $ \mathbb{N} = \{0, 1, 2, 3, \ldots \}$ are the _natural_ numbers.
# * $ \mathbb{Z} = \{ \ldots, -3, -2, -1, 0, 1, 2, 3, \ldots \} $
# * $ \mathbb{Q} = \{ \ldots, -\frac{1}{3}, -\frac{1}{2}, -\frac{1}{1}, \frac{1}{1}, \frac{1}{2}, \frac{1}{3}, \ldots \} $
#
# * A bijection is one-to-one correspondence between two mathematical sets.
# <figure style="text-align: center;">
#   <img src="images/bijection.png" alt="Vector" width="200">
#   <figcaption>Figure 1: A bijective function, f: X -> Y, a pairing between sets</figcaption>
# </figure>
#
# *  A set is **countable** if either it is finite or it can be made in one to one correspondence with the set of natural numbers.
# * A countable set that is not finite is said to be countably infinite.
# * Demonstrate a bijection between the natural numbers and the integers.
#
# <figure style="text-align: center;">
#   <img src="images/IntegersCountable.jpg" alt="Vector" width="200">
#   <figcaption>Figure 2: Bijection between naturals and integers</figcaption>
# </figure>
#
#
# * Demonstrate a bijection between the natural numbers and the rationals.
#
# <figure style="text-align: center;">
#   <img src="images/RationalsCountable.jpg" alt="Vector" width="200">
#   <figcaption>Figure 3: Bijection between naturals and rationals</figcaption>
# </figure>
#
# * Demonstrate that there is no bijection between reals and natural numbers. The real numbers are uncountably infinite.
#
# <figure style="text-align: center;">
#   <img src="images/RealsNotCountable.jpg" alt="Vector" width="200">
#   <figcaption>Figure 4: Uncountably infinite</figcaption>
# </figure>

# %%
import matplotlib.pyplot as plt

def bijection_integers_to_naturals(n):
    if n > 0:
        return (2 * n) - 1
    else: 
        return -2 * n

x_values = []
y_values = []

for n in range(-10, 11):
    x_values.append(bijection_integers_to_naturals(n))
    y_values.append(n)

# Sort the points by x_values
sorted_points = sorted(zip(x_values, y_values))
x_values_sorted, y_values_sorted = zip(*sorted_points)

# Plot the zigzagging line
plt.plot(x_values_sorted, y_values_sorted)
plt.xlabel("Natural Numbers")
plt.ylabel("Integers")
plt.title("Bijection Between Integers and Natural Numbers")
plt.show()
